# %% [markdown]
# Оценим изменение метрик при внесении полиномиальных признаков.
# Применим регуляризационные модели

# %% [markdown]
# # Импорт библиотек и данных

# %% [markdown]
# Launch a server via:
# ```bash
# mlflow server --host 127.0.0.1 --port 8080
# ```

# %%
import sys
from pathlib import Path

import pandas as pd
import numpy as np

from sklearn.preprocessing import PolynomialFeatures

# from sklearn.feature_selection import RFE, SelectKBest, f_regression

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge, Lasso, LassoCV, ElasticNetCV

root_folder = '../'
sys.path.append(root_folder)

from src.models import train_model, predict_model
from src.utils import get_dict

train_path = Path(root_folder, 'data', 'processed', '2.0_train.csv')
test_path = Path(root_folder, 'data', 'processed', '2.0_test.csv')

experiment_name = 'Housing cost'

# %% [markdown]
# Загрузим датасеты:

# %%
train = pd.read_csv(train_path, index_col=0)
train.info()
X_train, y_train = train_model.get_X_y(train, target_name='log_target')
print()
print()

test = pd.read_csv(test_path, index_col=0)
test.info()
X_test, y_test = train_model.get_X_y(test, target_name='log_target')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 264639 entries, 0 to 264638
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   baths                            264639 non-null  float64
#  1   fireplace                        264639 non-null  bool
#  2   beds                             264639 non-null  float64
#  3   stories                          264639 non-null  float64
#  4   private_pool                     264639 non-null  bool
#  5   parking_count                    264639 non-null  float64
#  6   central_heating                  264639 non-null  bool
#  7   central_cooling                  264639 non-null  bool
#  8   log_target                       264639 non-null  float64
#  9   log_sqft                         264639 non-null  float64
#  10  log_lotsize                      264639 non-null  float64
#  11  updated_years                    264639 non-null  float64
#  12  school_count                     264639 non-null  float64
#  13  min_log_school_distance          264639 non-null  float64
#  14  median_log_school_distance       264639 non-null  float64
#  15  median_school_rating             264639 non-null  float64
#  16  status_contract/new              264639 non-null  bool
#  17  status_foreclosure/pending       264639 non-null  bool
#  18  state_CA                         264639 non-null  bool
#  19  state_FL                         264639 non-null  bool
#  20  state_NC                         264639 non-null  bool
#  21  state_NY                         264639 non-null  bool
#  22  state_OH                         264639 non-null  bool
#  23  state_TN                         264639 non-null  bool
#  24  state_TX                         264639 non-null  bool
#  25  state_WA                         264639 non-null  bool
#  26  state_other                      264639 non-null  bool
#  27  property_type_condo              264639 non-null  bool
#  28  property_type_land/mobile        264639 non-null  bool
#  29  property_type_multi              264639 non-null  bool
#  30  property_type_ranch/traditional  264639 non-null  bool
#  31  property_type_single             264639 non-null  bool
#  32  property_type_styled             264639 non-null  bool
#  33  property_type_town               264639 non-null  bool
#  34  parking_type_garage              264639 non-null  bool
#  35  parking_type_other               264639 non-null  bool
#  36  heating_type_central             264639 non-null  bool
#  37  heating_type_electric            264639 non-null  bool
#  38  heating_type_gas/pump            264639 non-null  bool
#  39  cooling_type_other               264639 non-null  bool
#  40  cooling_type_refrigeration/fan   264639 non-null  bool
# dtypes: bool(29), float64(12)
# memory usage: 33.6 MB
# X shape: (264639, 40)
# y shape: (264639,)
#
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 66160 entries, 0 to 66159
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   baths                            66160 non-null  float64
#  1   fireplace                        66160 non-null  bool
#  2   beds                             66160 non-null  float64
#  3   stories                          66160 non-null  float64
#  4   private_pool                     66160 non-null  bool
#  5   parking_count                    66160 non-null  float64
#  6   central_heating                  66160 non-null  bool
#  7   central_cooling                  66160 non-null  bool
#  8   log_target                       66160 non-null  float64
#  9   log_sqft                         66160 non-null  float64
#  10  log_lotsize                      66160 non-null  float64
#  11  updated_years                    66160 non-null  float64
#  12  school_count                     66160 non-null  float64
#  13  min_log_school_distance          66160 non-null  float64
#  14  median_log_school_distance       66160 non-null  float64
#  15  median_school_rating             66160 non-null  float64
#  16  status_contract/new              66160 non-null  bool
#  17  status_foreclosure/pending       66160 non-null  bool
#  18  state_CA                         66160 non-null  bool
#  19  state_FL                         66160 non-null  bool
#  20  state_NC                         66160 non-null  bool
#  21  state_NY                         66160 non-null  bool
#  22  state_OH                         66160 non-null  bool
#  23  state_TN                         66160 non-null  bool
#  24  state_TX                         66160 non-null  bool
#  25  state_WA                         66160 non-null  bool
#  26  state_other                      66160 non-null  bool
#  27  property_type_condo              66160 non-null  bool
#  28  property_type_land/mobile        66160 non-null  bool
#  29  property_type_multi              66160 non-null  bool
#  30  property_type_ranch/traditional  66160 non-null  bool
#  31  property_type_single             66160 non-null  bool
#  32  property_type_styled             66160 non-null  bool
#  33  property_type_town               66160 non-null  bool
#  34  parking_type_garage              66160 non-null  bool
#  35  parking_type_other               66160 non-null  bool
#  36  heating_type_central             66160 non-null  bool
#  37  heating_type_electric            66160 non-null  bool
#  38  heating_type_gas/pump            66160 non-null  bool
#  39  cooling_type_other               66160 non-null  bool
#  40  cooling_type_refrigeration/fan   66160 non-null  bool
# dtypes: bool(29), float64(12)
# memory usage: 8.4 MB
# X shape: (66160, 40)
# y shape: (66160,)

# %% [markdown]
# ## Ridge

# %% [markdown]
# Сконструируем `ColumnTranformer`:
# - Признаки с 'float64' проходят через `float_transformer`, состоящий из `StandardScaler` и `PolynomialFeatures` (степени 3)
# - Остальные признаки (как правило bool) проходят через `minmax_transformer`
#
# Далее идёт `SimpleImputer` на случай, если при использовании этой модели попадутся NaN-ы.
# Сейчас пропусков нет.
#
# В конце - модель Ridge c L2-регуляризацией

# %%
imputer_params = get_dict(
    missing_values=np.nan,
    strategy='median'
)

float_columns = list(X_train.columns[X_train.dtypes == 'float64'])

min_max_columns = list(
    set(X_train.columns) - set(float_columns)
)

float_transformer = Pipeline(
    [
        ('scaler', StandardScaler()),
        ('polynom', PolynomialFeatures(3))
    ]
)

transformers = [
    ('float_transformer', float_transformer, float_columns),
    ('minmax_transformer', MinMaxScaler(), min_max_columns)
]

pipe_elements = [
    ('column_transformer', ColumnTransformer, transformers),
    ('imputer', SimpleImputer, imputer_params),
    ('regressor', Ridge)
]

pipe, pipe_params = train_model.make_pipeline(pipe_elements)
display(pipe)

# Conduct fitting and cross-validation metrics estimation
cv_metrics = predict_model.cross_validate_pipe(
    pipe=pipe,
    X=X_train,
    y=y_train,
    njobs=3
)

pipe.fit(X_train, y_train)
metrics = predict_model.get_train_test_metrics(
    pipe,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
)
metrics = metrics | cv_metrics
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('float_transformer',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('polynom',
#                                                                    PolynomialFeatures(degree=3))]),
#                                                   ['baths', 'beds', 'stories',
#                                                    'parking_count', 'log_sqft',
#                                                    'log_lotsize',
#                                                    'updated_years',
#                                                    'school_count',
#                                                    'min_log_school_distance',
#                                                    'median_log_school_distance',
#                                                    'median_school_rati...
#                                                    'state_NY',
#                                                    'property_type_ranch/traditional',
#                                                    'state_OH',
#                                                    'heating_type_electric',
#                                                    'state_TX',
#                                                    'status_foreclosure/pending',
#                                                    'property_type_styled',
#                                                    'state_CA',
#                                                    'central_heating',
#                                                    'state_TN',
#                                                    'heating_type_gas/pump',
#                                                    'property_type_multi',
#                                                    'property_type_single',
#                                                    'central_cooling',
#                                                    'state_WA'])])),
#                 ('imputer', SimpleImputer(strategy='median')),
#                 ('regressor', Ridge())])
#          cv_train cv_validation
# mape_log    0.033         0.033
# r2_log      0.587         0.585
#       train   test
# mape  0.473  0.475
# r2    0.464  0.446

# %%
model_info = predict_model.log_pipe_mlflow(
    pipe_name='ridge-pf',
    training_info='Ridge regression with PF and StandardTransform',
    X=X_train,
    pipe=pipe,
    pipe_params=pipe_params,
    metrics=metrics,
    experiment_name=experiment_name,
)
# Out:
# Successfully registered model 'ridge-pf'.
# 2024/04/24 21:22:22 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: ridge-pf, version 1
# Created version '1' of model 'ridge-pf'.

# %% [markdown]
# Удалось получить меньший процент ошибки `MAPE`, чем в обоих бейзлайнах: $47.5$% против 49.2% на Decision tree и 53.1% у LinearRegression.
#
# $R^2 = 0.446$ лучше чем у линейной регресси (0.39), но хуже, чем у дерева решений (0.492)

# %% [markdown]
# ## Lasso

# %% [markdown]
# Проверим Lasso (L1-регуляризацию)

# %%
imputer_params = get_dict(
    missing_values=np.nan,
    strategy='median'
)

float_columns = list(X_train.columns[X_train.dtypes == 'float64'])

min_max_columns = list(
    set(X_train.columns) - set(float_columns)
)

float_transformer = Pipeline(
    [
        ('scaler', StandardScaler()),
        ('polynom', PolynomialFeatures(3))
    ]
)

transformers = [
    ('float_transformer', float_transformer, float_columns),
    ('minmax_transformer', MinMaxScaler(), min_max_columns)
]

pipe_elements = [
    ('column_transformer', ColumnTransformer, transformers),
    ('imputer', SimpleImputer, imputer_params),
    ('regressor', Lasso)
]

pipe, pipe_params = train_model.make_pipeline(pipe_elements)
display(pipe)

# Conduct fitting and cross-validation metrics estimation
cv_metrics = predict_model.cross_validate_pipe(
    pipe=pipe,
    X=X_train,
    y=y_train,
    njobs=3
)

pipe.fit(X_train, y_train)
metrics = predict_model.get_train_test_metrics(
    pipe,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
)
metrics = metrics | cv_metrics
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('float_transformer',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('polynom',
#                                                                    PolynomialFeatures(degree=3))]),
#                                                   ['baths', 'beds', 'stories',
#                                                    'parking_count', 'log_sqft',
#                                                    'log_lotsize',
#                                                    'updated_years',
#                                                    'school_count',
#                                                    'min_log_school_distance',
#                                                    'median_log_school_distance',
#                                                    'median_school_rati...
#                                                    'state_NY',
#                                                    'property_type_ranch/traditional',
#                                                    'state_OH',
#                                                    'heating_type_electric',
#                                                    'state_TX',
#                                                    'status_foreclosure/pending',
#                                                    'property_type_styled',
#                                                    'state_CA',
#                                                    'central_heating',
#                                                    'state_TN',
#                                                    'heating_type_gas/pump',
#                                                    'property_type_multi',
#                                                    'property_type_single',
#                                                    'central_cooling',
#                                                    'state_WA'])])),
#                 ('imputer', SimpleImputer(strategy='median')),
#                 ('regressor', Lasso())])
#          cv_train cv_validation
# mape_log    0.053         0.053
# r2_log      0.000        -0.000
#        train    test
# mape   0.894   0.886
# r2    -0.085  -0.086

# %% [markdown]
# Получили плохие результаты, попробуем применить `LassoCV`, которая итеративно подбирает на кросс-валидации свои гиперпараметры

# %%
imputer_params = get_dict(
    missing_values=np.nan,
    strategy='median'
)

float_columns = list(X_train.columns[X_train.dtypes == 'float64'])

min_max_columns = list(
    set(X_train.columns) - set(float_columns)
)

float_transformer = Pipeline(
    [
        ('scaler', StandardScaler()),
        ('polynom', PolynomialFeatures(3))
    ]
)

transformers = [
    ('float_transformer', float_transformer, float_columns),
    ('minmax_transformer', MinMaxScaler(), min_max_columns)
]

pipe_elements = [
    ('column_transformer', ColumnTransformer, transformers),
    ('imputer', SimpleImputer, imputer_params),
    ('regressor', LassoCV)
]

pipe, pipe_params = train_model.make_pipeline(pipe_elements)
display(pipe)

pipe.fit(X_train, y_train)
metrics = predict_model.get_train_test_metrics(
    pipe,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
)
metrics = metrics # | cv_metrics
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('float_transformer',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('polynom',
#                                                                    PolynomialFeatures(degree=3))]),
#                                                   ['baths', 'beds', 'stories',
#                                                    'parking_count', 'log_sqft',
#                                                    'log_lotsize',
#                                                    'updated_years',
#                                                    'school_count',
#                                                    'min_log_school_distance',
#                                                    'median_log_school_distance',
#                                                    'median_school_rati...
#                                                    'state_NY',
#                                                    'property_type_ranch/traditional',
#                                                    'state_OH',
#                                                    'heating_type_electric',
#                                                    'state_TX',
#                                                    'status_foreclosure/pending',
#                                                    'property_type_styled',
#                                                    'state_CA',
#                                                    'central_heating',
#                                                    'state_TN',
#                                                    'heating_type_gas/pump',
#                                                    'property_type_multi',
#                                                    'property_type_single',
#                                                    'central_cooling',
#                                                    'state_WA'])])),
#                 ('imputer', SimpleImputer(strategy='median')),
#                 ('regressor', LassoCV())])
#       train   test
# mape  0.477  0.478
# r2    0.449  0.434

# %%
model_info = predict_model.log_pipe_mlflow(
    pipe_name='lasso-pf',
    training_info='Lasso regression with PF and StandardTransform',
    X=X_train,
    pipe=pipe,
    pipe_params=pipe_params,
    metrics=metrics,
    experiment_name=experiment_name,
)
# Out:
# /home/vulf/.cache/pypoetry/virtualenvs/housing-cost-EeioB1ZZ-py3.11/lib/python3.11/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/vulf/.cache/pypoetry/virtualenvs/housing-cost-EeioB1ZZ-py3.11/lib/python3.11/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'lasso-pf'.
# 2024/04/24 21:40:30 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: lasso-pf, version 1
# Created version '1' of model 'lasso-pf'.

# %% [markdown]
# Результаты оказались несколько хуже, чем в случае с Ridge

# %% [markdown]
# ## ElasticNet

# %% [markdown]
# Посмотрим на комбинацию первых двух моделей с подбором параметров на кросс-валидации.

# %%
imputer_params = get_dict(
    missing_values=np.nan,
    strategy='median'
)

float_columns = list(X_train.columns[X_train.dtypes == 'float64'])

min_max_columns = list(
    set(X_train.columns) - set(float_columns)
)

float_transformer = Pipeline(
    [
        ('scaler', StandardScaler()),
        ('polynom', PolynomialFeatures(3))
    ]
)

transformers = [
    ('float_transformer', float_transformer, float_columns),
    ('minmax_transformer', MinMaxScaler(), min_max_columns)
]

pipe_elements = [
    ('column_transformer', ColumnTransformer, transformers),
    ('imputer', SimpleImputer, imputer_params),
    ('regressor', ElasticNetCV)
]

pipe, pipe_params = train_model.make_pipeline(pipe_elements)
display(pipe)

pipe.fit(X_train, y_train)
metrics = predict_model.get_train_test_metrics(
    pipe,
    X_train=X_train,
    X_test=X_test,
    y_train=y_train,
    y_test=y_test,
)
metrics = metrics # | cv_metrics
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('float_transformer',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler()),
#                                                                   ('polynom',
#                                                                    PolynomialFeatures(degree=3))]),
#                                                   ['baths', 'beds', 'stories',
#                                                    'parking_count', 'log_sqft',
#                                                    'log_lotsize',
#                                                    'updated_years',
#                                                    'school_count',
#                                                    'min_log_school_distance',
#                                                    'median_log_school_distance',
#                                                    'median_school_rati...
#                                                    'property_type_ranch/traditional',
#                                                    'state_OH',
#                                                    'heating_type_electric',
#                                                    'state_TX',
#                                                    'status_foreclosure/pending',
#                                                    'property_type_styled',
#                                                    'state_CA',
#                                                    'central_heating',
#                                                    'state_TN',
#                                                    'heating_type_gas/pump',
#                                                    'property_type_multi',
#                                                    'property_type_single',
#                                                    'central_cooling',
#                                                    'state_WA'])])),
#                 ('imputer', SimpleImputer(strategy='median')),
#                 ('regressor', ElasticNetCV())])
#       train   test
# mape  0.477  0.478
# r2    0.447  0.431

# %%
model_info = predict_model.log_pipe_mlflow(
    pipe_name='elasticnet-pf',
    training_info='ElasticNet regression with PF and StandardTransform',
    X=X_train,
    pipe=pipe,
    pipe_params=pipe_params,
    metrics=metrics,
    experiment_name=experiment_name,
)
# Out:
# /home/vulf/.cache/pypoetry/virtualenvs/housing-cost-EeioB1ZZ-py3.11/lib/python3.11/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/vulf/.cache/pypoetry/virtualenvs/housing-cost-EeioB1ZZ-py3.11/lib/python3.11/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'elasticnet-pf'.
# 2024/04/24 21:45:48 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: elasticnet-pf, version 1
# Created version '1' of model 'elasticnet-pf'.

# %% [markdown]
# Тестовые метрики не улучшились по сравнению с Ridge

# %% [markdown]
# ## Выводы по применению PolynomialFeatures

# %% [markdown]
# Применение PolynomialFeatures и L2-регуляризации (Ridge) удалось добиться наилучшего результата по MAPE и R^2 уступающий только DecisionTree
#
# Удалось получить меньший процент ошибки `MAPE`, чем в обоих бейзлайнах: $47.5$% против 49.2% на Decision tree и 53.1% у LinearRegression.
#
# $R^2 = 0.446$ лучше чем у линейной регресси (0.39), но хуже, чем у дерева решений (0.492)
#
# Показатели лучшей модели (Ridge) на финальном тесте:
# - **MAPE**: $0.475$ (то есть ошибка $47.5\%$ против 49.2% на Decision tree и 53.1% у LinearRegression.)
# - **R^2**: $0.446$ (лучше чем у линейной регресси (0.39), но хуже, чем у дерева решений (0.492))
